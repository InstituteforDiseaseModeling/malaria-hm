# %% [markdown]
# # Malaria challenge trial calibration

# %% [markdown]
# ### A history matching approach to calibrating an empirical model of malaria infection and immunity
# ### For iter0 we will cut down parameter space by using the distribution of infection durations by age in the KND cohort in Navrongo, Ghana

# %% [markdown]
# # Import block

# %%
from IPython.extensions import autoreload
# %load_ext autoreload
# %autoreload 2
import os, glob, re, sys, json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# from wand.image import Image as WImage
from IPython.display import IFrame, display

from pyDOE import lhs
from history_matching import HistoryMatching, HistoryMatchingCut, quick_read, Basis

sns.set(font_scale=2)
sns.set_style("white")
# Out:
# Looks like you don't have CUDA, that's okay, we'll try using CPU but it will be SLOW!
# Looks like you don't have CUDA, that's okay, we'll try using CPU but it will be SLOW!

# %%
def fix_glob(pth):
    return re.sub('([\[\]])','[\\1]', pth)

# %% [markdown]
# # Configure parameters and data for history matching

# %%
cut_name = f'Density'
DROP_BIN_20 = True

# iteration = int(re.search(r'iter(\d+)', os.getcwd())) # Index of the current iteration
iteration = 0 
#list of exp_ids/folders that correspond to exp_ids from which our emulation will draw
exp_ids = ['ec09bd7c-2fb9-e911-a2c1-c4346bcb1555'] # TODO: only uses first for now, should loop
basedir = 'C:\git\Malaria-Uganda-PRISM'
datafile = os.path.join('..','reference data', 'Garki_df.csv')

# %%
# The implausibility threshold determines how willing we are to retain regions
# of parameter space that are inconsistent with the underlying data. A higher
# threshold is more risk averse in that potentially good regions are less likely
# to be rejected, however it will take more iterations/simulations to achieve results.
implausibility_threshold = 3
training_fraction = 0.75 # Fraction of simulations to use as training
discrepancy_std = 0.0 # Accounts for uncertainty w.r.t model structure
n_samples_to_generate_for_next_iter = 1000 # Number of simulations to conduct on this iteration

# %%
# Here we define the parameter names and ranges
params_file = os.path.join('..','Params.xlsx')
param_info = quick_read(params_file, 'Params').set_index('Name')
param_names = param_info.index.tolist()

params = param_info.index.values
n_params = param_info.shape[0] # We'll use this one place later
display(param_info)
# Out:
# Reading Params from ..\Params_5ee2d17e0a87c3b05b3e2873eb32c43b.hd5
#                                                Min     Max  \
# Name
# Gametocyte_Conversion_Draw_Mean                  1       6
# Gametocyte_Conversion_Draw_Std_Dev               0       1
# Biological_Age_Immune_Coefficient_PPP            0       3
# Biological_Age_Immune_Coefficient_TM            -1       1
# Cumulative_Exposure_Immune_Coefficient_PPP       0       3
# Cumulative_Exposure_Immune_Coefficient_TM       -1       1
# Malaria_Free_Interval_Immune_Coefficient_PPP     0       3
# Malaria_Free_Interval_Immune_Coefficient_TM     -1       1
# Recent_Exposure_Immune_Coefficient_PPP           0       3
# Recent_Exposure_Immune_Coefficient_TM           -1       1
# Strain_Diversity_Immune_Coefficient_PPP          0       3
# Strain_Diversity_Immune_Coefficient_TM          -1       1
# Scale_Factor_Age_a                               0      30
# Scale_Factor_Age_b                               0       2
# Scale_Factor_Cum_Exp_shape                       0      50
# Scale_Factor_Rec_Exp_steepness                   0     100
# Scale_Factor_Rec_Exp_midpoint                    0      20
# Scale_Factor_Free_Interval_a                     0       2
# Scale_Factor_Strain_Diversity_n                  0      10
# Diversity_From_Marginal_Prevalence               0     200
# Prevalence_Threshold_For_Diversity               0      10
# Concurrent_Infections_a                          0     100
# Concurrent_Infections_b                          0     100
# Concurrent_Infections_c                          0     100
# ActiveInfectionsScaleFactorPT                    0       1
# AgeScaleFactorPT                                 0       1
# Age_PT_Increment                                 0   10000
# Base_PT                                       1000  100000
# ClearedInfectionsScaleFactorPT                   0       1
# FreeIntervalScaleFactorPT                        0       1
# Individual_Variation_Magnitude_PT                0       1
# NumWavesScaleFactorPT                            0       1
# Wave_Vs_Infection_Relative_Weight                0     100
#
#                                                                                      MapTo
# Name
# Gametocyte_Conversion_Draw_Mean                            Gametocyte_Conversion_Draw_Mean
# Gametocyte_Conversion_Draw_Std_Dev                      Gametocyte_Conversion_Draw_Std_Dev
# Biological_Age_Immune_Coefficient_PPP                Biological_Age_Immune_Coefficient_PPP
# Biological_Age_Immune_Coefficient_TM                  Biological_Age_Immune_Coefficient_TM
# Cumulative_Exposure_Immune_Coefficient_PPP      Cumulative_Exposure_Immune_Coefficient_PPP
# Cumulative_Exposure_Immune_Coefficient_TM        Cumulative_Exposure_Immune_Coefficient_TM
# Malaria_Free_Interval_Immune_Coefficient_PPP  Malaria_Free_Interval_Immune_Coefficient_PPP
# Malaria_Free_Interval_Immune_Coefficient_TM    Malaria_Free_Interval_Immune_Coefficient_TM
# Recent_Exposure_Immune_Coefficient_PPP              Recent_Exposure_Immune_Coefficient_PPP
# Recent_Exposure_Immune_Coefficient_TM                Recent_Exposure_Immune_Coefficient_TM
# Strain_Diversity_Immune_Coefficient_PPP            Strain_Diversity_Immune_Coefficient_PPP
# Strain_Diversity_Immune_Coefficient_TM              Strain_Diversity_Immune_Coefficient_TM
# Scale_Factor_Age_a                                                      Scale_Factor_Age_a
# Scale_Factor_Age_b                                                      Scale_Factor_Age_b
# Scale_Factor_Cum_Exp_shape                                      Scale_Factor_Cum_Exp_shape
# Scale_Factor_Rec_Exp_steepness                              Scale_Factor_Rec_Exp_steepness
# Scale_Factor_Rec_Exp_midpoint                                Scale_Factor_Rec_Exp_midpoint
# Scale_Factor_Free_Interval_a                                  Scale_Factor_Free_Interval_a
# Scale_Factor_Strain_Diversity_n                            Scale_Factor_Strain_Diversity_n
# Diversity_From_Marginal_Prevalence                      Diversity_From_Marginal_Prevalence
# Prevalence_Threshold_For_Diversity                      Prevalence_Threshold_For_Diversity
# Concurrent_Infections_a                                            Concurrent_Infections_a
# Concurrent_Infections_b                                            Concurrent_Infections_b
# Concurrent_Infections_c                                            Concurrent_Infections_c
# ActiveInfectionsScaleFactorPT                                ActiveInfectionsScaleFactorPT
# AgeScaleFactorPT                                                          AgeScaleFactorPT
# Age_PT_Increment                                                          Age_PT_Increment
# Base_PT                                                                            Base_PT
# ClearedInfectionsScaleFactorPT                              ClearedInfectionsScaleFactorPT
# FreeIntervalScaleFactorPT                                        FreeIntervalScaleFactorPT
# Individual_Variation_Magnitude_PT                        Individual_Variation_Magnitude_PT
# NumWavesScaleFactorPT                                                NumWavesScaleFactorPT
# Wave_Vs_Infection_Relative_Weight                        Wave_Vs_Infection_Relative_Weight

# %% [markdown]
# ## Read in Sim Results

# %%
all_samples = []
all_results = []
for exp_id in exp_ids:
    
    print('-'*80, '\nExperiment:', exp_id)
    sim_results_fn = os.path.join(exp_id, 'analyzer_results.csv')
    print(sim_results_fn)
    sr = pd.read_csv(sim_results_fn, skipinitialspace=True)
    sr['Sample_Id'] = sr['sample'].apply(lambda x: '%s.%06d' % (exp_id, x))
    sr.rename(columns = {'sim_id': 'Sim_Id','age_cat': 'AgeBin','value':'Result'}, inplace=True)
    all_results.append( sr )
    #read in tags making a samples.xlsx file 
    s = pd.read_excel(os.path.join(exp_id, 'Samples.xlsx'))
    # s.drop('Sim_Id', axis=1, inplace=True)
    s['Sample_Id'] = s['Sample'].apply(lambda x: '%s.%06d' % (exp_id, x))
    all_samples.append( s )

#.rename(columns={'level_1': 'Year', 0: 'Cases'}) \
all_results = pd.concat(all_results) \
    .set_index(['Sample_Id', 'Sim_Id', 'AgeBin']) \
    [['Result']] \
    .sort_index()

samples = pd.concat(all_samples).set_index('Sample_Id').sort_index() # Bad because sample will be repeated across exp_id!
                       
samples.to_csv('Samples.csv')
all_results.to_csv('Results_by_age.csv')
results = all_results['Result']

results = all_results[ 
        
        (all_results.index.get_level_values('AgeBin').isin(age_bin))
    ] \
    .groupby(['Sample_Id', 'Sim_Id']) \
    .mean()

    
results.rename(columns={'Result':'Sim_Result'}, inplace=True)

display(results.head())
# Out:
# --------------------------------------------------------------------------------
# Experiment: ec09bd7c-2fb9-e911-a2c1-c4346bcb1555
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555\analyzer_results.csv
#                                                                                   Sim_Result
# Sample_Id                                   Sim_Id
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000000 fb920485-2fb9-e911-a2c1-c4346bcb1555   67.111554
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000001 fc920485-2fb9-e911-a2c1-c4346bcb1555  103.813636
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000002 fd920485-2fb9-e911-a2c1-c4346bcb1555  107.324528
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000003 fe920485-2fb9-e911-a2c1-c4346bcb1555  107.461255
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000004 ff920485-2fb9-e911-a2c1-c4346bcb1555  118.942387

# %%
ref_data_path = os.path.join('..','reference data','GhanaDurations.xlsx')
ref_df = pd.read_excel(ref_data_path)

# how to set the cwd


desired_result_ref_age = ref_df.loc[ref_df['Age bin'] == int(age_bin[0][:2])]
desired_result = desired_result_ref_age['Mean']
desired_result_std = (desired_result_ref_age['CI_upper']-desired_result_ref_age['CI_lower'])/(2*1.96)

desired_result = desired_result.values[[0]].item()
desired_result_std = desired_result_std.values[[0]].item()

print('Before logit, desired result is %.3f [%.3f, %.3f]: ' % (desired_result, desired_result-2*desired_result_std, desired_result+2*desired_result_std))
# Out:
# Before logit, desired result is 129.000 [123.898, 134.102]:

# %%
z = pd.merge(samples, results, on='Sample_Id') # Return to Sample_Id

#sub in variables here, can be list of tuples
xyvars = [('Biological_Age_Immune_Coefficient_PPP',	'Biological_Age_Immune_Coefficient_TM'
)]
for (xvar, yvar) in xyvars:
    fig = plt.figure(figsize=(6,6))
    plt.scatter(z[xvar], z[yvar], c=100*z['Sim_Result'], s=1*z['Sim_Result'], cmap='jet')
    plt.xlabel(xvar); plt.ylabel(yvar)
    plt.xlim([param_info.loc[xvar, 'Min'], param_info.loc[xvar, 'Max']])
    plt.ylim([param_info.loc[yvar, 'Min'], param_info.loc[yvar, 'Max']])
    # TODO: Show as surface and plot desired result as isocline
plt.show()

# %%
# Finally we get to do some History Matching!
# Begin by creating an instance of the HistoryMatching class
ext = 'svg' # Filetype for figures produced by history matching
hm = HistoryMatching(
    cut_name = cut_name,
    param_info = param_info,
    inputs = samples,
    results = results.squeeze(),
    desired_result = desired_result,
    desired_result_var = desired_result_std**2,
    iteration = iteration,
    implausibility_threshold = implausibility_threshold,
    discrepancy_var = discrepancy_std**2,
    training_fraction = training_fraction,
    fig_type = ext
)
hm.save() # Save to disk
# Out:
# Welcome to IDM History Matching!
# Found 128 unique parameter configurations, each of which is repeated 1 time(s).
# --> Training with 96 unique parameter configurations ( 96  simulations including replicates)
# --> Testing  with 32  unique parameter configurations ( 32 simulations including replicates)

# %%
try:
    existing_basis = True
    need_basis = True
    with open(os.path.join('Cuts', cut_name, 'basis_glm.json')) as data_file:
        config = json.load( data_file )
        basis_glm = Basis.deserialize(config['Basis'])
        fitted_values = pd.read_json(config['Fitted_Values'], orient='split').set_index(['Sample_Id', 'Sim_Id']).squeeze()
except:
    existing_basis = False
    
if existing_basis:
    print('Found existing GLM basis with the following terms:')
    display(basis_glm.model_terms)
    reply = input('Would you like to use this basis? [Y]/n: ')
    
    if reply.lower() != 'n':
        need_basis = False
    
if need_basis:
    basis_glm = Basis.polynomial_basis(params=param_names, intercept = True, first_order=True, second_order=True, third_order=False, param_info=param_info)

    basis_glm.plot_regularize(samples, results, alpha = np.logspace(-5, -2, 15), scaleX=True)
    alpha_glm = float(input('What would you like to use for the GLM regularization parameter, alpha_glm = '))
#     alpha_glm = 1e-1
    
    fitted_values = basis_glm.regularize(samples, results, alpha = alpha_glm, scaleX=True)
    print('Regularization for GLM selected:\n', ' *','\n * '.join(basis_glm.get_terms()))
    with open(os.path.join('Cuts', cut_name, 'basis_glm.json'), 'w') as fout:
        json.dump( {
            'Basis': basis_glm.serialize(),
            'Fitted_Values': fitted_values.reset_index().to_json(orient='split')
        }, fout, indent=4)
# Out:
# Found existing GLM basis with the following terms:
# [Term([]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Recent_Exposure_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Strain_Diversity_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Scale_Factor_Age_b')]),
#  Term([EvalFactor('Age_PT_Increment')]),
#  Term([EvalFactor('Recent_Exposure_Immune_Coefficient_TM ** 2')]),
#  Term([EvalFactor('Strain_Diversity_Immune_Coefficient_TM ** 2')]),
#  Term([EvalFactor('Scale_Factor_Strain_Diversity_n ** 2')]),
#  Term([EvalFactor('Concurrent_Infections_a ** 2')]),
#  Term([EvalFactor('FreeIntervalScaleFactorPT ** 2')]),
#  Term([EvalFactor('Gametocyte_Conversion_Draw_Std_Dev * Malaria_Free_Interval_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Gametocyte_Conversion_Draw_Std_Dev * Strain_Diversity_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Biological_Age_Immune_Coefficient_PPP * Malaria_Free_Interval_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Biological_Age_Immune_Coefficient_PPP * Strain_Diversity_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Biological_Age_Immune_Coefficient_TM * Malaria_Free_Interval_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Biological_Age_Immune_Coefficient_TM * NumWavesScaleFactorPT')]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_PPP * Scale_Factor_Rec_Exp_midpoint')]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_PPP * Scale_Factor_Free_Interval_a')]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_PPP * Concurrent_Infections_b')]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_TM * Recent_Exposure_Immune_Coefficient_PPP')]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_TM * Strain_Diversity_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Malaria_Free_Interval_Immune_Coefficient_TM * Scale_Factor_Free_Interval_a')]),
#  Term([EvalFactor('Recent_Exposure_Immune_Coefficient_PPP * Recent_Exposure_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Recent_Exposure_Immune_Coefficient_TM * Strain_Diversity_Immune_Coefficient_TM')]),
#  Term([EvalFactor('Strain_Diversity_Immune_Coefficient_PPP * Concurrent_Infections_c')]),
#  Term([EvalFactor('Strain_Diversity_Immune_Coefficient_TM * AgeScaleFactorPT')]),
#  Term([EvalFactor('Scale_Factor_Age_b * Scale_Factor_Cum_Exp_shape')]),
#  Term([EvalFactor('Scale_Factor_Free_Interval_a * Prevalence_Threshold_For_Diversity')]),
#  Term([EvalFactor('Scale_Factor_Strain_Diversity_n * Age_PT_Increment')]),
#  Term([EvalFactor('Diversity_From_Marginal_Prevalence * Base_PT')]),
#  Term([EvalFactor('ActiveInfectionsScaleFactorPT * Age_PT_Increment')]),
#  Term([EvalFactor('NumWavesScaleFactorPT * Wave_Vs_Infection_Relative_Weight')])]
# Would you like to use this basis? [Y]/n: Y

# %%
# Now fit the glm and plot

### GLM ###############################################################
print("="*80, "\nGeneralized Linear Modeling\n", "="*80)
#######################################################################
f = hm.glm(
    basis = basis_glm,
    family = 'Poisson',
    force_optimize_glm = True,
    glm_fit_maxiter = 100000,
    plot = True, #force_optimize_glm,
    plot_data = False
)
# Out:
# ================================================================================
# Generalized Linear Modeling
#  ================================================================================
# Plotting

# %%
for file in glob.glob(fix_glob(os.path.join(hm.glmdir, "PairwiseResults", "*.%s"%ext))):
    img = IFrame(file, width=800, height=600)
    print(file)
    display(img)

# %%
# Results get saved to disk, so load and display:
for file in glob.glob(fix_glob(os.path.join(hm.glmdir, "GLM Predicted vs Actual*.%s"%ext))):
    img = IFrame(file, width=800, height=600)
    print(file)
    display(img)
# Out:
# ..\iter0\Cuts\Duration for\GLM\GLM Predicted vs Actual.svg
#         <iframe
#             width="800"
#             height="600"
#             src="..\iter0\Cuts\Duration for\GLM\GLM Predicted vs Actual.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
basis_gpr = Basis.polynomial_basis(
    params =  ['Scale_Factor_Age_a', 'Scale_Factor_Age_b','Biological_Age_Immune_Coefficient_PPP',
'Biological_Age_Immune_Coefficient_TM',
'Cumulative_Exposure_Immune_Coefficient_PPP',
'Cumulative_Exposure_Immune_Coefficient_TM'
              ],
#     params = param_info.index.values, #
    intercept = False, 
    first_order = True, 
    param_info=param_info)

# %%
### GPR ###############################################################
print("="*80, "\nGaussian Process Regression\n", "="*80)
#######################################################################
hm.gpr(
    basis = basis_gpr,
    force_optimize_gpr = True,

    sigma2_f_guess = 0.6,
    sigma2_f_bounds = (0.1, 1000),
    sigma2_n_guess =  2.0,
    sigma2_n_bounds = (0.01, 100),

    #lengthscale_guess = [0.09844299, 0.1256657, 0.0976875, 0.09889085, 0.1051974, 0.0950809, 0.10032171, 0.10599185, 0.10627393, 0.09950996, 0.09445544, 0.10285915, 0.10007409, 0.09847433, 0.08963389, 0.10205652, 0.09360044, 0.1024141, 0.09786228, 0.10247492, 0.09852253, 0.09632744, 0.09997534, 0.10767302, 0.10095249, 0.09941825, 0.10214923, 0.10221497, 0.09734157, 0.09093285, 0.10780673, 0.09881377, 0.10597152],
    lengthscale_guess = 0.25,
    lengthscale_bounds = (0.01, 100),

    optimize_sigma2_n = True,
    log_transform = False,

    verbose = True,
    optimizer_options = {
        'eps': 5e-3,
        'disp': True,
        'maxiter': 15000,
        'ftol': 2 * np.finfo(float).eps,
        'gtol': 2 * np.finfo(float).eps,
    },
    plot = True, #force_optimize_gpr,
    plot_data = False
)
# Out:
# ================================================================================
# Gaussian Process Regression
#  ================================================================================
# Autoinit GPU device name: GeForce GTX 965M
# Backing up gpr model to ..\iter0\Cuts\Duration for\GPR\model_2019_08_07_10_00_23.json
# Fitting the GPR
#
# 	LL: 150.31906591231285
# 	Theta: [0.6  2.   0.25 0.25 0.25 0.25 0.25 0.25]
# 	Deriv: [ 5.03675984 11.91272609  0.1978439  -1.99031427  0.17207949 -2.17070752
#  -0.24624471 -0.5673144 ]
#
# 	LL: 2014.916393059812
# 	Theta: [0.1        0.01       0.0521561  2.24031427 0.07792051 2.42070752
#  0.49624471 0.8173144 ]
# 	Deriv: [-7.29444974e+03 -1.32882619e+05  2.97694411e+03  5.80857783e+01
#   6.89397048e+03  2.64661907e+01  7.58647413e+02  4.15394368e+02]
#
# 	LL: 140.55510705922256
# 	Theta: [0.43219413 1.33213264 0.18360126 0.91797283 0.1922481  0.97851492
#  0.33264262 0.44039737]
# 	Deriv: [ 1.98593067 11.1589714   1.79778849  0.09485861  0.86042083 -0.45804732
#   0.94770945  0.13773548]
#
# 	LL: 684.3903895344589
# 	Theta: [0.1        0.01       0.01       1.34645202 0.01       1.62656128
#  0.08439197 0.52689983]
# 	Deriv: [ -5079.29343213 -17056.22944622   9727.67519029     51.12718256
#    7392.20680436     25.11468313   1193.01264013    238.33710407]
#
# 	LL: 136.43684204945308
# 	Theta: [0.32209012 0.89391869 0.12606203 1.05999002 0.13184292 1.1933065
#  0.25036124 0.46906816]
# 	Deriv: [-2.36931138  2.84500647  4.60016867  0.45882659  3.27782699 -0.36847251
#   3.86810054  1.26952196]
#
# 	LL: 135.60412163267733
# 	Theta: [0.32501097 0.54151066 0.01       1.06336047 0.01       1.29491656
#  0.01       0.406362  ]
# 	Deriv: [-7.99662498e+00 -9.86313972e+00  4.07472108e+01  3.14518546e-01
#   7.28228213e+01 -3.78260447e-02 -9.34912149e+01  1.82824491e+00]
# 	Theta: [1.00307443 0.44197054 0.06043491 0.40018544 0.23219332 8.23985716
#  0.06025458 0.16669146]
# 	Deriv: [ 0.21809356 -0.26622041  3.1579079  -1.72573156 -0.40537916 -0.04574138
#  -8.28116901  3.28800569]
#
# 	LL: 128.01488602571044
# 	Theta: [0.99987419 0.45070627 0.05933717 0.42820607 0.24580209 8.27853702
#  0.06342005 0.16708903]
# 	Deriv: [ 0.09991032  0.14653012  0.11978554 -1.4976938   0.41733656 -0.04693122
#   0.24953572  2.86195926]
#
# 	LL: 127.93851705838146
# 	Theta: [0.99141028 0.45153374 0.0540018  0.50327369 0.26428547 8.25350667
#  0.06156642 0.16414947]
# 	Deriv: [ 0.18044124 -0.2312356  -3.05863604 -0.92125459  0.95103195 -0.04748265
#   1.26290707  1.50366226]
#
# 	LL: 127.88980842997519
# 	Theta: [0.99521029 0.4511686  0.0554348  0.57618437 0.26383602 8.12540501
#  0.06184572 0.1608228 ]
# 	Deriv: [ 0.07581728 -0.72312847  0.18692522 -0.4759008   1.03930213 -0.04925891
#  -0.26290596  0.46901497]
#
# 	LL: 127.86245900688812
# 	Theta: [0.98363301 0.4572356  0.05416927 0.65399638 0.26222974 8.02265673
#  0.06149124 0.16051949]
# 	Deriv: [ 0.02099377 -0.37995306  0.61204079 -0.22372342  0.88358376 -0.0493819
#  -0.98947729  0.18700916]
#
# 	LL: 127.84590431215881
# 	Theta: [0.96762107 0.46430746 0.05365091 0.70022447 0.24186147 7.97024973
#  0.06294777 0.16080112]
# 	Deriv: [-0.05433075  0.39521696 -0.61233719 -0.1313358   0.2152559  -0.04764303
#   1.0232629   0.44645631]
#
# 	LL: 127.84396714604262
# 	Theta: [0.97037571 0.46328112 0.05396896 0.7131104  0.23754541 7.94876754
#  0.06293088 0.15983493]
# 	Deriv: [-0.0311761   0.32573391 -0.11385044 -0.09020792  0.06604126 -0.04761617
#   0.18256955  0.20381673]
#
# 	LL: 127.84265996730285
# 	Theta: [0.97139011 0.46236187 0.0541116  0.72462894 0.23594098 7.95019095
#  0.06285429 0.15923764]
# 	Deriv: [-0.03189063  0.20943668  0.3228987  -0.05580992  0.01530326 -0.04749446
#  -0.34805368  0.05403794]
#
# 	LL: 127.84045521426177
# 	Theta: [0.96974264 0.46114674 0.05388953 0.74166494 0.2349102  7.98390386
#  0.06265292 0.15840525]
# 	Deriv: [-0.04615957  0.01995452  0.60439262 -0.01227346 -0.01624021 -0.04690988
#  -0.75016763 -0.12584718]
#
# 	LL: 127.83636399121454
# 	Theta: [0.96167389 0.46068819 0.05395952 0.76648881 0.23550066 8.11071577
#  0.06255374 0.15727914]
# 	Deriv: [-0.15134934 -0.24437868  1.6919182   0.05226569  0.0453381  -0.04529781
#  -0.93689677 -0.26535187]
#
# 	LL: 127.82972644970658
# 	Theta: [0.94775254 0.45862674 0.0519431  0.79513832 0.23590773 8.37162131
#  0.0618068  0.15494132]
# 	Deriv: [-0.18822316 -0.61146934  0.57502706  0.0957161   0.03629497 -0.04187866
#  -0.57971964 -0.66852411]
LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.00049333, -0.00378589, -0.001541  , -0.00013404,  0.00164288,
#        -0.00036371, -0.00032226, -0.00102132])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 123
#       nit: 52
#    status: 2
#   success: False
#         x: array([1.08045200e+00, 4.59261028e-01, 5.80555940e-02, 7.88740964e-01,
#        2.63992854e-01, 1.00000000e+02, 6.60970935e-02, 1.67216593e-01])
# GPR evaluating training data
# GPR evaluating test data
# Plotting

# %%
pi = param_info.loc[basis_gpr.param_dict.keys()].reset_index()
pi['Lengthscale'] = hm.gpr_model.theta[2:]
print(pi[['Name', 'Lengthscale']].sort_values('Lengthscale'))
# Out:
#                                          Name  Lengthscale
# 0                          Scale_Factor_Age_a     0.058056
# 4  Cumulative_Exposure_Immune_Coefficient_PPP     0.066097
# 5   Cumulative_Exposure_Immune_Coefficient_TM     0.167217
# 2       Biological_Age_Immune_Coefficient_PPP     0.263993
# 1                          Scale_Factor_Age_b     0.788741
# 3        Biological_Age_Immune_Coefficient_TM   100.000000

# %%
# Results get saved to disk, so load and display:
for file in glob.glob(fix_glob(os.path.join(hm.gprdir, "PairwiseResults", "*.%s"%ext))):
    img = IFrame(file, width=800, height=600)
    print(file)
    display(img)

# %%
### Implausibility ############################################################
print("="*80, "\nImplausibility\n", "="*80)
###############################################################################
hm.calc_and_plot_implausibility(
    plot = True,
    do_plot_data = False,
    plot_data_highlight = pd.DataFrame() #hm.test_data.loc['prime.000049']
) 
    #plot_data_highlight=pd.DataFrame() # plot_data_highlight=hm.training_data.loc['prime.000049']

hm.training_data.to_excel(os.path.join('Cuts', cut_name, 'train_data.xlsx'))
hm.test_data.to_excel(os.path.join('Cuts', cut_name, 'test_data.xlsx'))

print('Good')
# Out:
# ================================================================================
# Implausibility
#  ================================================================================
# Good

# %%
# Results get saved to disk, so load and display:
for file in glob.glob(fix_glob(os.path.join(hm.combineddir, "*.%s"%ext))):
    img = IFrame(file, width=800, height=600)
    print(file)
    display(img)
# Out:
# ..\iter0\Cuts\Duration for\Implausibility\implausibility.svg
#         <iframe
#             width="800"
#             height="600"
#             src="..\iter0\Cuts\Duration for\Implausibility\implausibility.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
ar = all_results.reset_index()

data = ar.loc[ar['AgeBin']==age_bin[0]].groupby(['Sample_Id','AgeBin'])['Result'].mean().reset_index().set_index('Sample_Id')

train = hm.training_data
train['Train'] = True
test = hm.test_data
test['Train'] = False
train_test = pd.concat([train, test])

fig, ax = plt.subplots(figsize=(16,10))

# Reference
#ref_by_year = reference_data[['Prevalence']].reset_index()

ref_by_year = ref_df.loc[ref_df['Age bin'] == int(age_bin[0][:2])] \
    .groupby('Age bin') \
    .mean() \
    .reset_index()
print(ref_by_year)
print(data)
sns.lineplot(data=ref_by_year, x='Age bin', y='Mean', color='k', marker='o', alpha=1, lw=2, zorder=1);

# Sims
tmp = data.merge(train_test[['Sample_Orig', 'Implausible', 'Train']], left_on='Sample_Id', right_on='Sample_Orig')
print(tmp.head())
sns.lineplot(data=tmp, x='AgeBin', y='Result', hue='Implausible', style='Train', 
             units='Sample_Orig', estimator=None, alpha=0.5, lw=0.5,
             ax=ax, zorder=-1)
ax.set_xlabel('AgeBin');
ax.set_ylabel('Duration');
ax.set_xticks(ref_by_year['Age bin'].unique());
# Out:
#    Age bin  Mean  CI_lower  CI_upper
# 0       20   129       124       134
#                                                 AgeBin      Result
# Sample_Id
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000000  20.0-40.0   67.111554
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000001  20.0-40.0  103.813636
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000002  20.0-40.0  107.324528
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000003  20.0-40.0  107.461255
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000004  20.0-40.0  118.942387
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000005  20.0-40.0  135.280335
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000006  20.0-40.0  110.524390
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000007  20.0-40.0  129.502058
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000008  20.0-40.0  100.584416
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000009  20.0-40.0   72.747748
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000010  20.0-40.0  127.191235
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000011  20.0-40.0  123.625000
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000012  20.0-40.0   95.147410
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000013  20.0-40.0   63.636364
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000014  20.0-40.0  100.368889
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000015  20.0-40.0   98.442804
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000016  20.0-40.0  146.025641
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000017  20.0-40.0   95.167331
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000018  20.0-40.0  103.827309
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000019  20.0-40.0   74.382488
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000020  20.0-40.0  131.625000
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000021  20.0-40.0  103.805447
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000022  20.0-40.0  120.680162
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000023  20.0-40.0  109.063559
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000024  20.0-40.0   70.406250
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000025  20.0-40.0  108.985240
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000026  20.0-40.0  131.809524
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000027  20.0-40.0  127.174797
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000028  20.0-40.0   96.717391
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000029  20.0-40.0   78.579592
# ...                                                ...         ...
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000098  20.0-40.0  126.830882
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000099  20.0-40.0  100.178082
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000100  20.0-40.0  131.070539
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000101  20.0-40.0   87.936937
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000102  20.0-40.0  126.437768
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000103  20.0-40.0  112.992000
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000104  20.0-40.0   81.352713
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000105  20.0-40.0  118.294821
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000106  20.0-40.0   91.152074
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000107  20.0-40.0   86.937743
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000108  20.0-40.0  118.580392
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000109  20.0-40.0  114.308333
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000110  20.0-40.0  121.748936
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000111  20.0-40.0  115.296000
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000112  20.0-40.0   69.749020
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000113  20.0-40.0  110.204000
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000114  20.0-40.0  111.915612
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000115  20.0-40.0  105.391489
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000116  20.0-40.0  122.878641
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000117  20.0-40.0  105.224576
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000118  20.0-40.0  117.863208
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000119  20.0-40.0   88.613043
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000120  20.0-40.0  129.102564
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000121  20.0-40.0   92.231092
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000122  20.0-40.0  126.724907
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000123  20.0-40.0  114.654472
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000124  20.0-40.0  124.462810
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000125  20.0-40.0  118.930894
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000126  20.0-40.0  110.436782
# ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000127  20.0-40.0  122.085106
#
# [128 rows x 2 columns]
#       AgeBin      Result                                  Sample_Orig  \
# 0  20.0-40.0   67.111554  ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000000
# 1  20.0-40.0  103.813636  ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000001
# 2  20.0-40.0  107.324528  ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000002
# 3  20.0-40.0  107.461255  ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000003
# 4  20.0-40.0  118.942387  ec09bd7c-2fb9-e911-a2c1-c4346bcb1555.000004
#
#    Implausible  Train
# 0         True   True
# 1         True   True
# 2         True   True
# 3         True   True
# 4        False   True
